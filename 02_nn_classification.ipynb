# %% [markdown]
# <a href="https://colab.research.google.com/github/desaraju02/ai_ml_dl/blob/main/02_nn_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %% [markdown]
# ### Creating data to view and fit

# %%
from sklearn.datasets import make_circles
n_samples = 1000

# Create circles
X, y = make_circles(n_samples=n_samples, noise=0.03, random_state=42)

# %% [markdown]
# ### Lets visualize data

# %%
circles = pd.DataFrame({'X0':X[:,0], 'X1':X[:,1], 'target':y})
circles.head()
# Out:
#          X0        X1  target
# 0  0.754246  0.231481       1
# 1 -0.756159  0.153259       1
# 2 -0.815392  0.173282       1
# 3 -0.393731  0.692883       1
# 4  0.442208 -0.896723       0

# %% [markdown]
# ### Visuallize with Plot

# %%
# Either of the below is fine
# plt.scatter(x=circles['X0'], y=circles['X1'], c=circles['target'], cmap=plt.cm.RdYlBu)
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.RdYlBu)
plt.show()

# %% [markdown]
# ### Input and Output Shapes

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
X[0], y[0]
# Out:
# (array([0.75424625, 0.23148074]), 1)

# %% [markdown]
# ### Steps in Modelling

# %%
tf.random.set_seed(42)

# %%
tf.__version__
# Out:
# '2.18.0'

# %%
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)])

# %%
model_1.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['accuracy'])

# %%
#model_1.fit(tf.expand_dims(X[:,0], axis=-1), tf.expand_dims(X[:,1], axis=-1), epochs=100)
model_1.fit(X,y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5054 - loss: 0.7000
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5063 - loss: 0.6965
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4941 - loss: 0.6954
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4865 - loss: 0.6950
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4792 - loss: 0.6949
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4557 - loss: 0.6948
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4430 - loss: 0.6948
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4266 - loss: 0.6948
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4388 - loss: 0.6948
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4402 - loss: 0.6948
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4401 - loss: 0.6948
# Epoch 12/100
# ...

# %%
tf.random.set_seed(42)
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(1)])
model_2.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['accuracy'])
model_2.fit(X,y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4689 - loss: 4.3703
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5054 - loss: 7.3804
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5170 - loss: 7.6996
# Epoch 12/100
# ...

# %% [markdown]
# ### Improving our model
#
#
#
# *   Create a model - Add more layers or increase the number of neurons
# *   Compiling the model - Different optimizer like Adam
# *   Fitting a model -  Perhaps we might fit our model for more epochs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
### Below works perfectly
# model_3 = tf.keras.Sequential([
#     tf.keras.layers.Dense(100, activation='relu'),
#     tf.keras.layers.Dense(10, activation='relu'),
#     tf.keras.layers.Dense(1)])

model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)])

model_3.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

model_3.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4517 - loss: 4.0359
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4596 - loss: 0.7444
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4667 - loss: 0.7034
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4431 - loss: 0.6946
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4486 - loss: 0.6953
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4526 - loss: 0.6956
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4597 - loss: 0.6958
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4587 - loss: 0.6961
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4594 - loss: 0.6963
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4593 - loss: 0.6965
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4564 - loss: 0.6967
# Epoch 12/100
# ...

# %%
model_3.evaluate(X,y)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5133 - loss: 0.6917
# [0.695577085018158, 0.49300000071525574]

# %%
model_3.predict(X)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[ 1.5815345 ],
#        [ 1.8214259 ],
#        [ 1.2976676 ],
#        [ 1.4092442 ],
#        [-0.6403158 ],
#        [ 1.2338274 ],
#        [ 1.4900427 ],
#        [ 1.6188805 ],
#        [ 1.6105152 ],
#        [-0.90502894],
#        [ 1.2114741 ],
#        [-0.8442837 ],
#        [ 1.0694013 ],
#        [ 1.5169444 ],
#        [ 1.2055953 ],
#        [ 1.7230787 ],
#        [-0.41164222],
#        [ 1.6711783 ],
#        [ 1.3871734 ],
#        [-0.30136037],
#        [ 1.9623605 ],
#        [-0.7349102 ],
#        [-0.27140632],
#        [ 1.5842007 ],
#        [-0.6778297 ],
#        [-0.04619917],
#        [-0.77808934],
#        [ 1.1233388 ],
#        [ 1.3910382 ],
#        [ 1.5041907 ],
#        [ 0.06003812],
#        [-0.7548895 ],
#        [ 1.6955512 ],
#        [-0.73359334],
#        [-1.0592898 ],
#        [-0.9653026 ],
#        [ 1.3530221 ],
#        [ 1.1557729 ],
#        [ 1.6070583 ],
# ...

# %%
### To visualize our models prediction, lets create a function plot-decision_boundary
### Take in a trained model, feature X and labels y
### create a meshgrid of the different X values
### Make predictions across the meshgrid
### Plot the predictions as well as a line between zones

# %%
def plot_decision_boundary(model, X, y):
    X_min, X_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(X_min, X_max, 100),
                         np.linspace(y_min, y_max, 100))

    ## Creat X value (we're going to make predictions here)
    X_in = np.c_[xx.ravel(), yy.ravel()]

    ## Make predictions
    y_pred = model.predict(X_in)

    # Check for multi-class
    if len(y_pred[0]) > 1:
        print("Doing multiclass classification")
        y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
    else:
        print("Doing binary classification")
        y_pred = np.round(y_pred).reshape(xx.shape)


    # Plot the decision boundary
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(),xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
# Cheout the prediction our model is making
plot_decision_boundary(model_3, X, y)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Doing binary classification
