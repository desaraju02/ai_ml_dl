# %% [markdown]
# <a href="https://colab.research.google.com/github/desaraju02/ai_ml_dl/blob/main/Bag_Of_Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('SMSSpamCollection', sep='\t', names=['label', 'message'])

# %%
df
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# ### Data Cleaning and Pre-processing

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(0, len(df)):
    review = re.sub('[^a-zA-Z]', ' ', df['message'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
len(corpus)
# Out:
# 5572

# %%
### Create Bag of Words Model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500)
X = cv.fit_transform(corpus).toarray()

# %%
X.shape
# Out:
# (5572, 2500)

# %%
### N grams

# %%
cv.vocabulary_
# Out:
# {'go': 853,
#  'point': 1593,
#  'crazi': 495,
#  'avail': 165,
#  'bugi': 300,
#  'great': 877,
#  'world': 2433,
#  'la': 1128,
#  'buffet': 299,
#  'cine': 413,
#  'got': 868,
#  'wat': 2363,
#  'ok': 1479,
#  'lar': 1140,
#  'joke': 1074,
#  'wif': 2401,
#  'oni': 1487,
#  'free': 792,
#  'entri': 661,
#  'wkli': 2422,
#  'comp': 450,
#  'win': 2405,
#  'fa': 704,
#  'cup': 509,
#  'final': 748,
#  'tkt': 2190,
#  'st': 2034,
#  'may': 1310,
#  'text': 2149,
#  'receiv': 1744,
#  'question': 1701,
#  'std': 2045,
#  'txt': 2247,
#  'rate': 1725,
#  'appli': 123,
#  'dun': 623,
#  'say': 1836,
#  'earli': 627,
#  'alreadi': 90,
#  'nah': 1416,
#  'think': 2164,
#  'goe': 856,
#  'usf': 2290,
#  'live': 1203,
#  'around': 138,
#  'though': 2170,
#  'freemsg': 794,
#  'hey': 933,
#  'darl': 528,
#  'week': 2378,
#  'word': 2430,
#  'back': 178,
#  'like': 1188,
#  'fun': 812,
#  'still': 2047,
#  'tb': 2125,
#  'xxx': 2461,
#  'chg': 396,
#  'send': 1864,
#  'rcv': 1728,
# ...

# %%
cv.vocabulary

# %%
cv = CountVectorizer(max_features=500, ngram_range=(2,3))
X = cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'free entri': 133,
#  'rate appli': 341,
#  'claim call': 61,
#  'call claim': 26,
#  'claim code': 62,
#  'call claim code': 27,
#  'updat latest': 441,
#  'latest colour': 216,
#  'free call': 130,
#  'call mobil': 38,
#  'updat latest colour': 442,
#  'chanc win': 59,
#  'win cash': 487,
#  'chanc win cash': 60,
#  'txt word': 434,
#  'dont miss': 108,
#  'let know': 220,
#  'feel like': 125,
#  'repli ye': 348,
#  'go home': 153,
#  'anyth lor': 5,
#  'call repli': 44,
#  'mobil free': 265,
#  'free camcord': 131,
#  'pleas call': 320,
#  'deliveri tomorrow': 104,
#  'lt gt': 236,
#  'miss call': 261,
#  'want go': 474,
#  'first time': 129,
#  'like lt': 223,
#  'like lt gt': 224,
#  'sm ac': 375,
#  'bx ip': 23,
#  'sorri call': 379,
#  'call later': 36,
#  'later meet': 214,
#  'sorri call later': 380,
#  'award bonu': 13,
#  'prize call': 334,
#  'ur award': 443,
#  'hi babe': 189,
#  'call free': 30,
#  'that cool': 414,
#  'hi hi': 191,
#  'wen ur': 486,
# ...
